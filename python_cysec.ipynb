# %%
import requests

# %%
r = requests.get('https://xkcd.com/comics/python.png')
# print(r.text)
# print(help(r))
with open('comic.png'.'wb') as f:
  f.write(r.content)
# Out:
#   File "<ipython-input-11-029683f169d8>", line 4
#     with open('comic.png'.'wb') as f:
#                              ^
# SyntaxError: invalid syntax
